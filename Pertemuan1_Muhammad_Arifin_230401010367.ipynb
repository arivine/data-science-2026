# %% [markdown]
# <a href="https://colab.research.google.com/github/arivine/data-science-2026/blob/main/Pertemuan1_Muhammad_Arifin_230401010367.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World, ini kuliah data Science")
# Out:
# Hello World, ini kuliah data Science

# %%
nama = "Muhammad Arifin" # String
angkatan = 2024 # Integer
jurusan = "PJJ-Informatika" #String

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"Jurusan : {jurusan}")
# Out:
# Nama : Muhammad Arifin
# Angkatan: 2024
# Jurusan : PJJ-Informatika

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i in tools:
    print(i)
# Out:
# Tools Data Science yang akan kita pelajari:
# Python
# Google Colab
# Jupyter Notebook
# GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Perkenalkan nama saya {nama} dari {prodi}, angkatan {angkatan}, Saya senang belajar python"

perkenalan("Arifin", "PJJ Informatika", 2024)
# Out:
# 'Hai! Perkenalkan nama saya Arifin dari PJJ Informatika, angkatan 2024, Saya senang belajar python'
